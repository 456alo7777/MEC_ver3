# %%
import pandas
import numpy 
from matplotlib import pyplot as plt

# %%
DQN = pandas.read_csv("DQL_5phut.csv")
FDQO = pandas.read_csv("FDQO_5phut.csv")
# MAB = pandas.read_csv(" MAB_5phut.csv")
# UCB = pandas.read_csv("UCB_5phut.csv")
Fuzzy = pandas.read_csv("Fuzzy_5phut.csv")
Frame=pandas.DataFrame(DQN["mean_reward"].values, columns = ["rewardDQN"])
Frame["rewardFDQO"] = FDQO["mean_reward"]
# Frame["rewardMAB"] = MAB["mean_reward"]
#Frame["rewardUCB"] = UCB["mean_reward"]
#Frame["rewardFuzzy"]  = Fuzzy["mean_reward"]
Frame.plot.line()
# Out:
# <AxesSubplot:>

# %%
ucb = pandas.read_csv("ucb.csv",header=None )
mab = pandas.read_csv("mab.csv",header=None )
fuzzy = pandas.read_csv("fuzzy.csv", header=None )
DQN = pandas.read_csv("DQN.csv", header=None )
FDQO = pandas.read_csv("FDQO.csv", header = None )
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_38953/168529263.py in <cell line: 3>()
#       1 # ucb = pandas.read_csv("ucb.csv",header=None )
#       2 # mab = pandas.read_csv("mab.csv",header=None )
# ----> 3 fuzzy = pandas.read_csv("fuzzy.csv", header=None )
#       4 DQN = pandas.read_csv("DQN.csv", header=None )
#       5 FDQO = pandas.read_csv("FDQO.csv", header = None )
#
# ~/.python/current/lib/python3.10/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
# ucb
# Out:
#                0
# 0       1.000000
# 1       1.000000
# 2       1.000000
# 3       1.000000
# 4       1.000000
# ...          ...
# 123946  0.884426
# 123947  0.884427
# 123948  0.884428
# 123949  0.884429
# 123950  0.884430
#
# [123951 rows x 1 columns]

# %%
df = pandas.DataFrame(ucb)
df["mab"] = mab
df["fuzzy"] = fuzzy
df["DQN"] = DQN
df["FDQO"] = FDQO
df
# Out:
#                0       mab     fuzzy       DQN      FDQO
# 0       1.000000  1.000000  1.000000  1.000000  1.000000
# 1       1.000000  1.000000  1.000000  1.000000  1.000000
# 2       1.000000  1.000000  1.000000  1.000000  1.000000
# 3       1.000000  1.000000  1.000000  1.000000  1.000000
# 4       1.000000  1.000000  1.000000  1.000000  1.000000
# ...          ...       ...       ...       ...       ...
# 123946  0.884426  0.877026  0.845529  0.975868  0.983714
# 123947  0.884427  0.877025  0.845528  0.975868  0.983713
# 123948  0.884428  0.877022  0.845525  0.975868  0.983713
# 123949  0.884429  0.877017  0.845521  0.975868  0.983713
# 123950  0.884430  0.877018  0.845522  0.975868  0.983713
#
# [123951 rows x 5 columns]

# %%
Frame=pandas.DataFrame(df.values, columns = ["ucb", "mab", "fuzzy", "DQN","FDQO"])

# %%
Frame.plot.line()
plt.show()
